# %%
print "program started"
a=raw_input("enter a value:")
b=raw_input("Enter b value:")
f=open('f1.txt','w')
f.write("a={0}, b={1}, ".format(a,b))
try:
    a=float(a)
    b=float(b)
    res=a/b
    f.write("res={0}".format(res))
except Exception as err:
    f.write(err)
    
f.close()    
print "other statements in python"
print "program ended"
# Out:
# program started
# enter a value:12
# Enter b value:6
# other statements in python
# program ended

# %%
print "program started"
a=raw_input("enter a value:")
b=raw_input("Enter b value:")
f=open('f1.txt','w')
f.write("a={0}, b={1}, ".format(a,b))
try:
    a=float(a)
    b=float(b)
    res=a/b
    f.write("res={0}".format(res))
except Exception as err:
    f.write(str(err))
    
f.close()    
print "other statements in python"
print "program ended"
# Out:
# program started
# enter a value:12
# Enter b value:0
# other statements in python
# program ended

# %%
print "program started"
a=raw_input("enter a value:")
b=raw_input("Enter b value:")
f=open('f1.txt','w')
f.write("a={0}, b={1}, ".format(a,b))
try:
    a=float(a)
    b=float(b)
    res=a/b
    f.write("res={0}".format(res))
except Exception as err:
    f.write(str(err))
finally:
    f.close()    
print "other statements in python"
print "program ended"
# Out:
# program started
# enter a value:12
# Enter b value:0
# other statements in python
# program ended

# %%
def fun():
    return 20
    return 30
    print "end of function"
print fun()
# Out:
# 20

# %%
def fun():
    try:
        return 20
    except:
        return 30
    finally:
        return 40
print fun()
# Out:
# 40

# %%
f=open('f1.txt','w')
f.write([1,2,3,4,5])
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-313c672ca5a7> in <module>()
#       1 f=open('f1.txt','w')
# ----> 2 f.write([1,2,3,4,5])
#       3 f.close()
#
# TypeError: expected a string or other character buffer object

# %%
f=open('f1.txt','w')
f.write(str([1,2,3,4,5]))
f.close()

# %%
data=open('f1.txt').read()

# %%
data
# Out:
# '[1, 2, 3, 4, 5]'

# %%
type(data)
# Out:
# str

# %%
persons = [{'id':1,'name':'n1'},{'id':2,'name':'n2'}]
f=open('f1.txt','w')
f.write(str(persons))
f.close()

# %%
import pickle
persons = [{'id':1,'name':'n1'},{'id':2,'name':'n2'}]
f=open("f1.txt",'w')
pickle.dump(persons,f)
f.close()

# %%
f=open('f1.txt')
data = f.read()
print data
# Out:
# (lp0
# (dp1
# S'id'
# p2
# I1
# sS'name'
# p3
# S'n1'
# p4
# sa(dp5
# g2
# I2
# sg3
# S'n2'
# p6
# sa.

# %%
f=open('f1.txt')
data = pickle.load(f)
print data
# Out:
# [{'id': 1, 'name': 'n1'}, {'id': 2, 'name': 'n2'}]

# %%
type(data)
# Out:
# list

# %%
f=open('image1.png')
data = f.read()
print data
# Out:
# �PNG
#
# !��U7fU�m���Y�*�V
# gRRҹ����R�����
# !�����h[����p%����_g�
# A
# !�:m˖-m��|��W^,��G�����(*:::##����J
# bO/y���=;~�ZsK������Y�ȡC��
# �����VY}9u��+�;�A�A!���Nߘʁ<l�0_	C��︬msF]�?��Bn�{�[�r.sKqZ��Ǡ��`	��K�N-�)7�m����p�#��Q�3
# �l-����!�PO��|G*++322���m9��%(���C���L
#  B���r�f��!j�L5���{
# ��7�(�B"�]�ܖ/���'���J��u�����|�RB��Xuz+��L��GZ��C��7�g�Ƹ�KH�����}Ƿߊj5���yc��=��:b�P7�`צ�u���yڹ���F�?��H�{{ReE�i��ꧠ/4�;��3&��n"����;9[��o����7WH	�2j8���{^8���pr�xs�Ѵ
# �b
# ������9�_n�hbƏ��By��<r���1���s�"��	7'�J���-J#�!��`<�����Q��ě��K,�9��L�j����Ю��oI���
# G�	!��(
# !t��Y�/u�+��Pg�<XX
# ��-�1k�T:po���@��TR��K�����-���V��;lqIò�W3�%�[�Y2���C�!AW-Tt���̸c��	x��:@��<9�^�i����r/i��V�X@�
# �P�ޭ�y^�i��K�Jǫ�o}c�4U�7�?4��~~@<yћS�:L����C��KŪ+��O觸����U�3ut������,�5��������_���j��j�֭�߿�����o�_�8��iAtd��[��Z��ߚ�����C��Zm�?k�vu�θ�9����g��Ӫ�?�����yբ;T�V}y��
# �xH���P0tT��ߔ52��Ƽ�_����&p	��g�-��#�g�����g����6����ǖ����M.��
# ���7�8�䔽�گ�����Ӥ-�'��k¼���%��?�Z���2w%��rM�W�	��G
# ...

# %%
f=open('image1.png')
data = f.read()
f.close()
f=open('image2.png','w')
f.write(data)
f.close()

# %%
f=open('image1.png','rb')
data = f.read()
f.close()
f=open('image2.png','wb')
f.write(data)
f.close()

# %%
https://github.com/sambapython/python/blob/master/assignments.txt 59-69
# Out:
#   File "<ipython-input-22-21b848b17322>", line 1
#     https://github.com/sambapython/python/blob/master/assignments.txt
#          ^
# SyntaxError: invalid syntax
